# %%
# !pip install langchain_google_genai
# !pip install -U langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 33.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.5/471.5 kB 30.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.79
#     Uninstalling langchain-core-0.3.79:
#       Successfully uninstalled langchain-core-0.3.79
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
api_key = "Add your api-key"
# GET YOURS AT https://aistudio.google.com/api-keys
# openrouter
# avalai

# %%
import pandas as pd


columns = ["Full Name", "Birth Year", "Birth Place", "Skin Color", "Height", "Profession"]


df = pd.DataFrame(columns=columns)


print(df)
# Out:
# Empty DataFrame
# Columns: [Full Name, Birth Year, Birth Place, Skin Color, Height, Profession]
# Index: []

# %%
# لیست پیشنهادی ۱۰ فرد مشهور
suggested_names = [
    "Albert Einstein", "Elon Musk", "Marie Curie",
    "Leonardo DiCaprio", "Serena Williams", "Steve Jobs",
    "Oprah Winfrey", "Lionel Messi", "Frida Kahlo", "Nelson Mandela"
]

print("لیست پیشنهادی من:")
print(suggested_names)


print("\nلطفاً اسامی مورد نظر خود را با ویرگول (,) جدا کنید.")
user_input = input("یا برای استفاده از همین لیست پیشنهادی، فقط دکمه Enter را بزنید: ")


if user_input.strip():

    famous_people = [name.strip() for name in user_input.split(",")]
else:

    famous_people = suggested_names

print("\nلیست نهایی برای استخراج اطلاعات:")
print(famous_people)
# Out:
# لیست پیشنهادی من:
# ['Albert Einstein', 'Elon Musk', 'Marie Curie', 'Leonardo DiCaprio', 'Serena Williams', 'Steve Jobs', 'Oprah Winfrey', 'Lionel Messi', 'Frida Kahlo', 'Nelson Mandela']
#
# لطفاً اسامی مورد نظر خود را با ویرگول (,) جدا کنید.
# یا برای استفاده از همین لیست پیشنهادی، فقط دکمه Enter را بزنید: Leonardo DiCaprio , Steve Jobs
#
# لیست نهایی برای استخراج اطلاعات:
# ['Leonardo DiCaprio', 'Steve Jobs']

# %%
# !pip install -U ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 75.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain-community ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 1.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.11
#     Uninstalling langchain-text-splitters-0.3.11:
#       Successfully uninstalled langchain-text-splitters-0.3.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from langchain_community.tools import DuckDuckGoSearchRun
from langchain.tools import tool
from langgraph.prebuilt import create_react_agent
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
import pandas as pd
from typing import Optional

# --- ابزار اول: جستجو در اینترنت ---
search_tool = DuckDuckGoSearchRun()

# --- ابزار دوم: ثبت اطلاعات (نسخه جدید و جایگزین شده) ---
@tool
def add_celebrity_to_table(
    full_name: str,
    birth_year: str,
    birth_place: str,
    profession: str,
    # پارامترهای اختیاری
    skin_color: Optional[str] = None,
    height: Optional[str] = None
):
    """
    Adds a row to the dataframe. Skin color and height are optional fields.
    Call this tool AFTER searching for the info.
    """
    global df
    new_row = {
        "Full Name": full_name,
        "Birth Year": birth_year,
        "Birth Place": birth_place,
        "Skin Color": skin_color,
        "Height": height,
        "Profession": profession
    }
    df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    return f"Successfully added {full_name} to the table."


tools = [search_tool, add_celebrity_to_table]




agent = create_react_agent(llm, tools=tools)


print("عامل هوشمند (نسخه Optional) در حال جستجو و استخراج اطلاعات است...\n")

for name in famous_people:
    print(f" در حال تحقیق درباره: {name} ...")

    query = f"""
    Search specifically for {name}'s details:
    1. Birth Year
    2. Birth Place
    3. Profession
    4. Skin Color (Optional)
    5. Height (Optional)

    Once you find these, IMMEDIATELY use the 'add_celebrity_to_table' tool to save them.
    """

    try:
        result = agent.invoke({"messages": [HumanMessage(content=query)]})
        print(f" وضعیت: {result['messages'][-1].content}\n")

    except Exception as e:
        print(f" خطا در پردازش {name}: {e}\n")


print("-" * 30)
print("جدول نهایی استخراج شده (با None/NaN):")
display(df)
# Out:
# /tmp/ipython-input-4065922049.py:45: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(llm, tools=tools)
# عامل هوشمند (نسخه Optional) در حال جستجو و استخراج اطلاعات است...
#
#  در حال تحقیق درباره: Leonardo DiCaprio ...
#  وضعیت: I have successfully added Leonardo DiCaprio to the table with the following details:
# Birth Year: 1974
# Birth Place: Los Angeles, California
# Profession: Actor
# Height: 1.83 m
#
#  در حال تحقیق درباره: Steve Jobs ...
#  وضعیت: I have added Steve Jobs to the table with the following details:
# Birth Year: 1955
# Birth Place: San Francisco, California
# Profession: Electronics sector professional (Co-founder of Apple Computer)
#
# ------------------------------
# جدول نهایی استخراج شده (با None/NaN):
# ...
